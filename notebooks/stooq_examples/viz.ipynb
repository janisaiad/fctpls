# %%
from fctpls.utils.viz.viz_stooq import make_stooq_figure  # we import viz helper
from fctpls.utils.data.curating_stooq import stooq_txt_to_df_5min

# %%
file_path = "../../data/stooq/hungary/5_hu_txt/data/5 min/hu/bse stocks/4ig.hu.txt"
df = stooq_txt_to_df_5min(file_path, tz="Europe/Paris")  # read this specific hourly file
fig = make_stooq_figure(df, ohlc_type="candlestick", add_mas=(20, 50), tz_display="Europe/Paris")
fig.show()

# %%
from fctpls.utils.viz.viz_stooq import make_stooq_figure  # we import viz helper
from fctpls.utils.data.curating_stooq import stooq_txt_to_df_hourly

# %%
file_path = "../../data/stooq/hungary/h_hu_txt/data/hourly/hu/bse stocks/4ig.hu.txt"
df = stooq_txt_to_df_hourly(file_path, tz="Europe/Paris")  # read this specific hourly file
fig = make_stooq_figure(df, ohlc_type="candlestick", add_mas=(20, 50), tz_display="Europe/Paris")
fig.show()

# %%
from fctpls.utils.viz.viz_stooq import make_stooq_figure  # we import viz helper
from fctpls.utils.data.curating_stooq import stooq_txt_to_df

# %%
file_path = "../../data/stooq/hungary/d_hu_txt/data/daily/hu/bse stocks/4ig.hu.txt"
df = stooq_txt_to_df_hourly(file_path, tz="Europe/Paris")  # read this specific hourly file
fig = make_stooq_figure(df, ohlc_type="candlestick", add_mas=(20, 50), tz_display="Europe/Paris")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 file_path = "../../data/stooq/hungary/d_hu_txt/data/daily/hu/bse stocks/4ig.hu.txt"
# ----> 2 df = stooq_txt_to_df_hourly(file_path, tz="Europe/Paris")  # read this specific hourly file
#       3 fig = make_stooq_figure(df, ohlc_type="candlestick", add_mas=(20, 50), tz_display="Europe/Paris")
#       4 fig.show()
#
# File ~/4A/evt/fctpls/utils/data/curating_stooq.py:211, in stooq_txt_to_df_hourly(file_path, tz)
#     200 def stooq_txt_to_df_hourly(file_path: Union[str, Path], tz: Optional[str] = None) -> pd.DataFrame:
#     201     '''
#     202     we parse a stooq txt file and return only hourly (60-minute) bars with validated timestamps  # we describe the purpose
#     203
#    (...)    209         a dataframe filtered to per=="60" with timestamps at hh:00:00  # we describe return
#     210     '''
# ...
